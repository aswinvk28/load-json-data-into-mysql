# %%
# !pip install wget==3.2

# %%
import os
import sys
import re
import wget
import tarfile
import gzip
from io import BytesIO

# %%
# file name for importing JSON
output_filename = os.environ.get('output_filename', 'Software.json')

# file data storage location
data_dir = os.environ.get('data_dir', './data')

# %%
parameters = list(
    map(lambda s: re.sub('$', '"', s),
        map(
            lambda s: s.replace('=', '="'),
            filter(
                lambda s: s.find('=') > -1 and bool(re.match(r'[A-Za-z0-9_]*=[.\/A-Za-z0-9]*', s)),
                sys.argv
            )
    )))

for parameter in parameters:
    logging.warning('Parameter: ' + parameter)
    exec(parameter)

# %%
wget.download("http://deepyeti.ucsd.edu/jianmo/amazon/categoryFiles/Software.json.gz")
# Out:
#   0% [                                                                        ]    40960 / 98221392
#   0% [                                                                        ]   212992 / 98221392
#   0% [                                                                        ]   671744 / 98221392
#   1% [.                                                                       ]  1433600 / 98221392
#   2% [..                                                                      ]  2842624 / 98221392
#   4% [..                                                                      ]  3997696 / 98221392
#   5% [...                                                                     ]  5324800 / 98221392
#   7% [.....                                                                   ]  6963200 / 98221392
#   8% [.....                                                                   ]  8060928 / 98221392
# ...

# %%
with open("Software.json.gz", "rb") as f:
    inbuffer = BytesIO(f.read())
    with gzip.GzipFile(mode="rb", fileobj=inbuffer) as file:
        read_data = file.read()
    with open(os.path.join(data_dir, output_filename), 'wb') as out:
        out.write(read_data)
